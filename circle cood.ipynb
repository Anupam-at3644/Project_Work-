# %%
######## Bressanham Algorithm  ##########
import matplotlib.pyplot as plt
import numpy as np
x_0 = 200
y_0 = 400
def func(i,j,r):
    if ((i-0.5-x_0)**2 + (j+1-y_0)**2 - r**2 <= 0):
        return int(i), int(j+1)
    else: 
        return int(i-1), int(j+1)
ans = []
def circle(r=100):
    i, j = int(x_0+r), int(y_0)
    ans.append([int(i),int(j)])
    while(j-i+x_0-y_0<=0):
        i, j = func(i,j,r)
        ans.append([int(i),int(j)])
circle()
xc=[]
yc=[]
ans2 = ans.copy() 

for k in ans2:
    ans.append([int(k[1]+x_0-y_0), int(k[0]+y_0-x_0)])

ans2 = ans.copy()
for k in ans2:
    ans.append([k[0], int(2*y_0-k[1])])

ans2 = ans.copy()
for k in ans2:
    ans.append([int(2*x_0-k[0]), k[1]])

for k in ans:
    xc.append(k[0])
    yc.append(k[1])
# %matplotlib notebook
plt.scatter(xc,yc,s=1)
#plt.xlim(0,400)
#plt.ylim(0,400)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
import numpy as np
def circle(x,y,r,n,option):
    x_0 = x
    y_0 = y
    r = r
    n = n
    ans = []
    for i in range (n):
        if(option=='+'):
            x,y = np.ceil(x_0 + r * np.cos(360/n*i)), np.ceil(y_0 + r * np.sin(360/n*i))
        elif(option=='-'):
            x,y = np.floor(x_0 + r * np.cos(360/n*i)), np.floor(y_0 + r * np.sin(360/n*i))
        ans.append([x,y])
    x = []
    y = []
    for i in ans:
        x.append(i[0])
        y.append(i[1]) 
    return x,y
x,y =circle(200,400,100,200,'+')
# %matplotlib notebook
plt.scatter(x,y,s=1)
x,y = circle(200,400,100,200,'-')
plt.scatter(x,y,s=1)
plt.xlim(0,600)
plt.ylim(0,600)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
